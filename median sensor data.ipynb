# %%
import pandas as pd

sensor_data = "007_eef6acc2-04c6-4876-bcec-a4144d89ff49.csv"

df_sensor = pd.read_csv(sensor_data, low_memory=False)


df_sensor.head()


# print(df_sensor['Timestamp'].dtype)
# print(df_phases['Time Started'].dtype)
# Out:
#    Row  Timestamp  EventSource  SlideEvent   StimType   Duration  \
# 0    1    36476.8          1.0  StartSlide  TestImage  3000000.0
# 1    2    36483.0          NaN         NaN        NaN        NaN
# 2    3    36486.0          NaN         NaN        NaN        NaN
# 3    4    36486.9          1.0  StartMedia  TestImage  3000000.0
# 4    5    36514.0          NaN         NaN        NaN        NaN
#
#   CollectionPhase SourceStimuliName  EventSource.1     Anger  ...  \
# 0  StimuliDisplay     Research Task            NaN       NaN  ...
# 1             NaN     Research Task            1.0  0.358904  ...
# 2             NaN     Research Task            1.0  0.767966  ...
# 3  StimuliDisplay     Research Task            NaN       NaN  ...
# 4             NaN     Research Task            1.0  0.367456  ...
#
#    Saccade Index  Saccade Index by Stimulus  Saccade Start  Saccade End  \
# 0            NaN                        NaN            NaN          NaN
# ...

# %%
# Create medians df
only_emotions_df = df_sensor[['Anger', 'Contempt', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Engagement', 'Sentimentality', 'Confusion']]
only_emotions_df.head()

general_medians = only_emotions_df[['Anger', 'Contempt', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Engagement', 'Sentimentality', 'Confusion']].median()
general_medians.head(20)
# Out:
# Anger              1.131056
# Contempt           0.189771
# Disgust            0.578211
# Fear               0.930716
# Joy                0.024571
# Sadness            0.121332
# Surprise           0.710729
# Engagement        56.017029
# Sentimentality     0.006020
# Confusion          0.103808
# dtype: float64
