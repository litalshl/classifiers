# %% [markdown]
# <h1>All Respondents Analysis with Grades Final</h1>

# %% [markdown]
# <h2>Read All Respondents Data</h2>

# %%
import os
import pandas as pd

# Specify the folder path where the CSV files are located
folder_path = "../../all respondents data"

# Initialize an empty dataframe to store the combined data
combined_data = pd.DataFrame()

# Loop through each file in the folder with .csv extension and append to the combined_data dataframe
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path, low_memory=False)
        respondent_num = filename.split('_')[0]  # Get the first part of the filename before the first '_'
        df['Respondent'] = respondent_num  # Add a new column with the respondent number
        combined_data = pd.concat([combined_data, df])

columns_to_remove = ['Row','EventSource','SlideEvent','StimType','Duration',
                     'CollectionPhase','SourceStimuliName','EventSource','SampleNumber','EventSource.1',
                     'BlinkRate', 'EventSource.2','Interocular Distance', 'Gaze X', 'Gaze Y', 'Interpolated Gaze X',
                    'Interpolated Gaze Y', 'Interpolated Distance', 'Fixation Index', 'Fixation Index by Stimulus',
                    'Fixation X', 'Fixation Y', 'Fixation Start', 'Fixation End', 'Saccade Index',
                    'Saccade Index by Stimulus', 'Saccade Start', 'Saccade End', 'Gaze Velocity', 'Gaze Acceleration', 'Fixation Duration',
                    'Fixation Dispersion', 'Saccade Duration', 'Saccade Amplitude',
                    'Saccade Peak Velocity', 'Saccade Peak Acceleration',
                    'Saccade Peak Deceleration', 'Saccade Direction']
combined_data.drop(columns_to_remove, axis=1, inplace=True)

combined_data.head()
# Out:
#    Timestamp     Anger  Contempt   Disgust      Fear       Joy   Sadness  \
# 0  36101.200       NaN       NaN       NaN       NaN       NaN       NaN
# 1  36109.900       NaN       NaN       NaN       NaN       NaN       NaN
# 2  36236.000  0.125566  0.186393  0.023706  0.125796  0.025453  0.125512
# 3  36269.000  0.125833  0.186909  0.023738  0.126169  0.025312  0.125694
# 4  36270.473       NaN       NaN       NaN       NaN       NaN       NaN
#
#    Surprise  Engagement  Valence  ...  Mouth Open  Nose Wrinkle     Smile  \
# 0       NaN         NaN      NaN  ...         NaN           NaN       NaN
# 1       NaN         NaN      NaN  ...         NaN           NaN       NaN
# 2  0.055428    0.328766      0.0  ...    0.027488      0.008689  0.443331
# 3  0.055510    0.328766      0.0  ...    0.027396      0.013201  0.406091
# 4       NaN         NaN      NaN  ...         NaN           NaN       NaN
#
#    Smirk  Upper Lip Raise  Blink     Pitch       Yaw      Roll  Respondent
# 0    NaN              NaN    NaN       NaN       NaN       NaN         001
# 1    NaN              NaN    NaN       NaN       NaN       NaN         001
# 2    0.0         0.000345    0.0  6.757946 -1.150817 -0.977193         001
# 3    0.0         0.000376    0.0  3.458502 -0.160348  0.267830         001
# 4    NaN              NaN    NaN       NaN       NaN       NaN         001
#
# [5 rows x 39 columns]

# %%
print(combined_data)
# Out:
#           Timestamp     Anger  Contempt   Disgust      Fear       Joy  \
# 0         36101.200       NaN       NaN       NaN       NaN       NaN
# 1         36109.900       NaN       NaN       NaN       NaN       NaN
# 2         36236.000  0.125566  0.186393  0.023706  0.125796  0.025453
# 3         36269.000  0.125833  0.186909  0.023738  0.126169  0.025312
# 4         36270.473       NaN       NaN       NaN       NaN       NaN
# ...             ...       ...       ...       ...       ...       ...
# 148355  2522681.800       NaN       NaN       NaN       NaN       NaN
# 148356  2522709.000  0.245047  0.204197  0.028027  0.133038  0.041089
# 148357  2522709.800       NaN       NaN       NaN       NaN       NaN
# 148358  2522831.900       NaN       NaN       NaN       NaN       NaN
# 148359  2522831.900       NaN       NaN       NaN       NaN       NaN
#
#          Sadness  Surprise  Engagement  Valence  ...  Mouth Open  \
# 0            NaN       NaN         NaN      NaN  ...         NaN
# 1            NaN       NaN         NaN      NaN  ...         NaN
# 2       0.125512  0.055428    0.328766      0.0  ...    0.027488
# 3       0.125694  0.055510    0.328766      0.0  ...    0.027396
# 4            NaN       NaN         NaN      NaN  ...         NaN
# ...          ...       ...         ...      ...  ...         ...
# 148355       NaN       NaN         NaN      NaN  ...         NaN
# 148356  0.118906  0.057576    0.328766      0.0  ...    7.659717
# 148357       NaN       NaN         NaN      NaN  ...         NaN
# 148358       NaN       NaN         NaN      NaN  ...         NaN
# 148359       NaN       NaN         NaN      NaN  ...         NaN
#
#         Nose Wrinkle     Smile     Smirk  Upper Lip Raise  Blink     Pitch  \
# 0                NaN       NaN       NaN              NaN    NaN       NaN
# 1                NaN       NaN       NaN              NaN    NaN       NaN
# 2           0.008689  0.443331  0.000000         0.000345    0.0  6.757946
# 3           0.013201  0.406091  0.000000         0.000376    0.0  3.458502
# 4                NaN       NaN       NaN              NaN    NaN       NaN
# ...              ...       ...       ...              ...    ...       ...
# 148355           NaN       NaN       NaN              NaN    NaN       NaN
# 148356      0.376117  4.076993  3.261096         0.070152    0.0 -0.172043
# 148357           NaN       NaN       NaN              NaN    NaN       NaN
# 148358           NaN       NaN       NaN              NaN    NaN       NaN
# 148359           NaN       NaN       NaN              NaN    NaN       NaN
#
#              Yaw      Roll  Respondent
# 0            NaN       NaN         001
# 1            NaN       NaN         001
# 2      -1.150817 -0.977193         001
# 3      -0.160348  0.267830         001
# 4            NaN       NaN         001
# ...          ...       ...         ...
# 148355       NaN       NaN         019
# 148356 -1.711222 -0.415041         019
# 148357       NaN       NaN         019
# 148358       NaN       NaN         019
# 148359       NaN       NaN         019
#
# [1433385 rows x 39 columns]

# %%
print(combined_data.columns)
# Out:
# Index(['Timestamp', 'Anger', 'Contempt', 'Disgust', 'Fear', 'Joy', 'Sadness',
#        'Surprise', 'Engagement', 'Valence', 'Sentimentality', 'Confusion',
#        'Neutral', 'Attention', 'Brow Furrow', 'Brow Raise', 'Cheek Raise',
#        'Chin Raise', 'Dimpler', 'Eye Closure', 'Eye Widen', 'Inner Brow Raise',
#        'Jaw Drop', 'Lip Corner Depressor', 'Lip Press', 'Lip Pucker',
#        'Lip Stretch', 'Lip Suck', 'Lid Tighten', 'Mouth Open', 'Nose Wrinkle',
#        'Smile', 'Smirk', 'Upper Lip Raise', 'Blink', 'Pitch', 'Yaw', 'Roll',
#        'Respondent'],
#       dtype='object')

# %%
# Specify the columns where NaN values should be removed
columns_to_check = ['Contempt','Eye Widen', 'Smirk', 'Sentimentality',
                 'Lip Stretch', 'Dimpler', 'Eye Closure', 'Blink', 'Confusion', 'Surprise', 'Joy', 'Smile']

# Remove rows with NaN values in specified columns
df_combined_cleaned = combined_data.dropna(subset=columns_to_check, how='all')

# Display the DataFrame after removing rows with NaN values
print("\nDataFrame after removing rows with NaN values:")
df_combined_cleaned.head()
# Out:
# DataFrame after removing rows with NaN values:
#     Timestamp     Anger  Contempt   Disgust      Fear       Joy   Sadness  \
# 2     36236.0  0.125566  0.186393  0.023706  0.125796  0.025453  0.125512
# 3     36269.0  0.125833  0.186909  0.023738  0.126169  0.025312  0.125694
# 5     36301.0  0.126258  0.187818  0.023798  0.126605  0.025114  0.125970
# 7     36333.0  0.126290  0.188413  0.023834  0.126583  0.024996  0.126124
# 10    36381.0  0.126344  0.188792  0.023866  0.126641  0.024909  0.126202
#
#     Surprise  Engagement  Valence  ...  Mouth Open  Nose Wrinkle     Smile  \
# 2   0.055428    0.328766      0.0  ...    0.027488      0.008689  0.443331
# 3   0.055510    0.328766      0.0  ...    0.027396      0.013201  0.406091
# 5   0.055607    0.328766      0.0  ...    0.030377      0.019631  0.341483
# 7   0.055529    0.328766      0.0  ...    0.029414      0.022291  0.300317
# 10  0.055519    0.328766      0.0  ...    0.025747      0.033456  0.273545
#
#     Smirk  Upper Lip Raise  Blink     Pitch       Yaw      Roll  Respondent
# 2     0.0         0.000345    0.0  6.757946 -1.150817 -0.977193         001
# 3     0.0         0.000376    0.0  3.458502 -0.160348  0.267830         001
# 5     0.0         0.000493    0.0  3.753664 -0.737176  0.388438         001
# 7     0.0         0.000636    0.0  4.180299 -0.449494  0.456045         001
# 10    0.0         0.000934    0.0  4.626769 -0.389839  0.613328         001
#
# [5 rows x 39 columns]

# %%
df_combined_cleaned.count()
# Out:
# Timestamp               936917
# Anger                   936917
# Contempt                936917
# Disgust                 936917
# Fear                    936917
# Joy                     936917
# Sadness                 936917
# Surprise                936917
# Engagement              936917
# Valence                 936917
# Sentimentality          936917
# Confusion               936917
# Neutral                 936917
# Attention               936917
# Brow Furrow             936917
# Brow Raise              936917
# Cheek Raise             936917
# Chin Raise              936917
# Dimpler                 936917
# Eye Closure             936917
# Eye Widen               936917
# Inner Brow Raise        936917
# Jaw Drop                936917
# Lip Corner Depressor    936917
# Lip Press               936917
# Lip Pucker              936917
# Lip Stretch             936917
# Lip Suck                936917
# Lid Tighten             936917
# Mouth Open              936917
# Nose Wrinkle            936917
# Smile                   936917
# Smirk                   936917
# Upper Lip Raise         936917
# Blink                   936917
# Pitch                   936917
# Yaw                     936917
# Roll                    936917
# Respondent              936917
# dtype: int64

# %% [markdown]
# <h3>Merge Respondents Data with Grades Dataframe</h3>

# %%
import pandas as pd

# Read in the Grades.csv file
grades_df = pd.read_csv('../Grades.csv')

# Remove the trailing underscore from the "Respondent" column in the grades_df dataframe
grades_df['Respondent'] = grades_df['Respondent'].str.rstrip('_')

# Merge the combined_data and grades_df dataframes based on the "Respondent" column
combined_data_with_grades = pd.merge(df_combined_cleaned, grades_df[['Respondent', 'Grade']], on='Respondent')

# Print the resulting dataframe with the added "Grade" column
print(combined_data_with_grades)
# Out:
#         Timestamp     Anger  Contempt   Disgust      Fear       Joy   Sadness  \
# 0         36236.0  0.125566  0.186393  0.023706  0.125796  0.025453  0.125512
# 1         36269.0  0.125833  0.186909  0.023738  0.126169  0.025312  0.125694
# 2         36301.0  0.126258  0.187818  0.023798  0.126605  0.025114  0.125970
# 3         36333.0  0.126290  0.188413  0.023834  0.126583  0.024996  0.126124
# 4         36381.0  0.126344  0.188792  0.023866  0.126641  0.024909  0.126202
# ...           ...       ...       ...       ...       ...       ...       ...
# 882821  2522583.0  0.139795  0.183797  0.026397  0.130016  0.045364  0.117328
# 882822  2522615.0  0.153553  0.176831  0.026905  0.128566  0.046042  0.116635
# 882823  2522647.0  0.168653  0.193708  0.027669  0.130344  0.045429  0.117382
# 882824  2522681.0  0.195341  0.187637  0.027562  0.130503  0.043328  0.117269
# 882825  2522709.0  0.245047  0.204197  0.028027  0.133038  0.041089  0.118906
#
#         Surprise  Engagement  Valence  ...  Nose Wrinkle     Smile     Smirk  \
# 0       0.055428    0.328766      0.0  ...      0.008689  0.443331  0.000000
# 1       0.055510    0.328766      0.0  ...      0.013201  0.406091  0.000000
# 2       0.055607    0.328766      0.0  ...      0.019631  0.341483  0.000000
# 3       0.055529    0.328766      0.0  ...      0.022291  0.300317  0.000000
# 4       0.055519    0.328766      0.0  ...      0.033456  0.273545  0.000000
# ...          ...         ...      ...  ...           ...       ...       ...
# 882821  0.060181    0.328766      0.0  ...      0.457276  4.720551  2.773993
# 882822  0.058846    0.328766      0.0  ...      0.512176  4.703412  2.382556
# 882823  0.058326    0.328766      0.0  ...      0.519497  4.585781  3.149543
# 882824  0.057809    0.328766      0.0  ...      0.463937  4.418400  2.717841
# 882825  0.057576    0.328766      0.0  ...      0.376117  4.076993  3.261096
#
#         Upper Lip Raise  Blink     Pitch       Yaw      Roll  Respondent  \
# 0              0.000345    0.0  6.757946 -1.150817 -0.977193         001
# 1              0.000376    0.0  3.458502 -0.160348  0.267830         001
# 2              0.000493    0.0  3.753664 -0.737176  0.388438         001
# 3              0.000636    0.0  4.180299 -0.449494  0.456045         001
# 4              0.000934    0.0  4.626769 -0.389839  0.613328         001
# ...                 ...    ...       ...       ...       ...         ...
# 882821         0.106491    0.0  1.251196 -1.319161 -0.530024         019
# 882822         0.255912    0.0  0.392811 -1.608518 -0.468374         019
# 882823         0.253990    0.0  0.286135 -1.387060 -0.229705         019
# 882824         0.150040    0.0 -1.702013 -1.998969 -0.185392         019
# 882825         0.070152    0.0 -0.172043 -1.711222 -0.415041         019
#
#         Grade
# 0         100
# 1         100
# 2         100
# 3         100
# 4         100
# ...       ...
# 882821     55
# 882822     55
# 882823     55
# 882824     55
# 882825     55
#
# [882826 rows x 40 columns]

# %%
combined_data_with_grades.head()
# Out:
#    Timestamp     Anger  Contempt   Disgust      Fear       Joy   Sadness  \
# 0    36236.0  0.125566  0.186393  0.023706  0.125796  0.025453  0.125512
# 1    36269.0  0.125833  0.186909  0.023738  0.126169  0.025312  0.125694
# 2    36301.0  0.126258  0.187818  0.023798  0.126605  0.025114  0.125970
# 3    36333.0  0.126290  0.188413  0.023834  0.126583  0.024996  0.126124
# 4    36381.0  0.126344  0.188792  0.023866  0.126641  0.024909  0.126202
#
#    Surprise  Engagement  Valence  ...  Nose Wrinkle     Smile  Smirk  \
# 0  0.055428    0.328766      0.0  ...      0.008689  0.443331    0.0
# 1  0.055510    0.328766      0.0  ...      0.013201  0.406091    0.0
# 2  0.055607    0.328766      0.0  ...      0.019631  0.341483    0.0
# 3  0.055529    0.328766      0.0  ...      0.022291  0.300317    0.0
# 4  0.055519    0.328766      0.0  ...      0.033456  0.273545    0.0
#
#    Upper Lip Raise  Blink     Pitch       Yaw      Roll  Respondent  Grade
# 0         0.000345    0.0  6.757946 -1.150817 -0.977193         001    100
# 1         0.000376    0.0  3.458502 -0.160348  0.267830         001    100
# 2         0.000493    0.0  3.753664 -0.737176  0.388438         001    100
# 3         0.000636    0.0  4.180299 -0.449494  0.456045         001    100
# 4         0.000934    0.0  4.626769 -0.389839  0.613328         001    100
#
# [5 rows x 40 columns]

# %%
print(combined_data_with_grades.columns)
# Out:
# Index(['Timestamp', 'Anger', 'Contempt', 'Disgust', 'Fear', 'Joy', 'Sadness',
#        'Surprise', 'Engagement', 'Valence', 'Sentimentality', 'Confusion',
#        'Neutral', 'Attention', 'Brow Furrow', 'Brow Raise', 'Cheek Raise',
#        'Chin Raise', 'Dimpler', 'Eye Closure', 'Eye Widen', 'Inner Brow Raise',
#        'Jaw Drop', 'Lip Corner Depressor', 'Lip Press', 'Lip Pucker',
#        'Lip Stretch', 'Lip Suck', 'Lid Tighten', 'Mouth Open', 'Nose Wrinkle',
#        'Smile', 'Smirk', 'Upper Lip Raise', 'Blink', 'Pitch', 'Yaw', 'Roll',
#        'Respondent', 'Grade'],
#       dtype='object')

# %% [markdown]
# <h2>Facial Expressions Analysis</h2>

# %% [markdown]
# <h3>Data Pre-processing</h3>

# %%
import pandas as pd

facial_expressions_columns = ['Respondent', 'Grade','Contempt','Eye Widen', 'Smirk', 'Sentimentality', 'Sadness',
                 'Lip Stretch', 'Dimpler', 'Eye Closure', 'Blink', 'Confusion', 'Surprise', 'Joy', 'Smile']
# Creating a copy df with only the facial expressions data
facial_expressions_data = combined_data_with_grades[facial_expressions_columns].copy()

# Remove rows with all NaN values, except in the 'Respondent' column
facial_expressions_data = facial_expressions_data.dropna(how='all', 
                                                         subset=facial_expressions_data.columns.difference(['Respondent', 'Grade']))

facial_expressions_data
# Out:
#        Respondent  Grade  Contempt  Eye Widen     Smirk  Sentimentality  \
# 0             001    100  0.186393   0.045593  0.000000        0.030948
# 1             001    100  0.186909   0.067544  0.000000        0.051102
# 2             001    100  0.187818   0.102596  0.000000        0.043316
# 3             001    100  0.188413   0.074720  0.000000        0.032416
# 4             001    100  0.188792   0.070817  0.000000        0.028298
# ...           ...    ...       ...        ...       ...             ...
# 882821        019     55  0.183797   0.314685  2.773993        0.487793
# 882822        019     55  0.176831   0.090651  2.382556        0.550477
# 882823        019     55  0.193708   0.028906  3.149543        0.589807
# 882824        019     55  0.187637   0.011203  2.717841        0.645367
# 882825        019     55  0.204197   0.003883  3.261096        0.701570
#
#          Sadness  Lip Stretch  Dimpler  Eye Closure  Blink  Confusion  \
# 0       0.125512     0.111019      0.0     2.229161    0.0   0.004428
# 1       0.125694     0.139556      0.0     6.476408    0.0   0.007234
# 2       0.125970     0.107941      0.0     7.173281    0.0   0.012638
# 3       0.126124     0.093415      0.0     9.601783    0.0   0.013319
# 4       0.126202     0.092498      0.0     3.474545    0.0   0.013363
# ...          ...          ...      ...          ...    ...        ...
# 882821  0.117328     0.189127      0.0    35.761505    0.0   0.487793
# 882822  0.116635     0.157140      0.0     2.597953    0.0   0.550477
# 882823  0.117382     0.145920      0.0     0.467741    0.0   0.589807
# 882824  0.117269     0.136352      0.0     0.642476    0.0   0.624019
# 882825  0.118906     0.138129      0.0     0.073778    0.0   0.554907
#
#         Surprise       Joy     Smile
# 0       0.055428  0.025453  0.443331
# 1       0.055510  0.025312  0.406091
# 2       0.055607  0.025114  0.341483
# 3       0.055529  0.024996  0.300317
# 4       0.055519  0.024909  0.273545
# ...          ...       ...       ...
# 882821  0.060181  0.045364  4.720551
# 882822  0.058846  0.046042  4.703412
# 882823  0.058326  0.045429  4.585781
# 882824  0.057809  0.043328  4.418400
# 882825  0.057576  0.041089  4.076993
#
# [882826 rows x 15 columns]

# %% [markdown]
# <h2>Compare Facial Expressions by Grade Group</h2>

# %%
from tabulate import tabulate

# Add a new column to the combined_data_with_grades dataframe that indicates whether the grade is above or below 55
facial_expressions_data['Grade Group'] = facial_expressions_data['Grade'].apply(lambda x: 'Above 55' if x > 55 else 'Below 55')

# Describe statistics for each selected column by grade group
selected_columns = ['Contempt','Eye Widen', 'Smirk', 'Sentimentality', 'Sadness',
                 'Lip Stretch', 'Dimpler', 'Eye Closure', 'Blink', 'Confusion', 'Surprise', 'Joy', 'Smile']

# %% [markdown]
# <h2>Correlation Between Emotions and Grade</h2>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

selected_columns = ['Contempt','Eye Widen', 'Smirk', 'Sentimentality', 'Sadness',
                 'Lip Stretch', 'Dimpler', 'Eye Closure', 'Blink', 'Confusion', 'Surprise', 'Joy', 'Smile']

plt.figure(figsize=(15, 10))  # Adjust figure size as needed

for col in selected_columns:
    plt.subplot(4, 9, selected_columns.index(col) + 1)  # Adjust layout based on the number of columns
    sns.histplot(data=facial_expressions_data, x=col, kde=True, bins=20)
    plt.title(f'Histogram of {col}')
    plt.xlabel('Values')
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


selected_columns_df = facial_expressions_data[['Contempt','Eye Widen', 'Smirk', 'Sentimentality', 'Sadness',
                 'Lip Stretch', 'Dimpler', 'Eye Closure', 'Blink', 'Confusion', 'Surprise', 'Joy', 'Smile', 'Grade']]

correlation_matrix = selected_columns_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix for Contempt')
plt.show()

# %% [markdown]
# <h3>Compare the Grade Groups</h3>

# %% [markdown]
# <h5>Using non-parametric statistical test, since the data distribution is not normal. Since the data is not ordered, since those are measures at different timestamps and therefore have no order, chose to use Wilcoxon statistical test</h6>

# %%
import pandas as pd
from scipy.stats import wilcoxon
import matplotlib.pyplot as plt

selected_columns = ['Contempt', 'Smirk', 'Eye Widen', 'Eye Closure', 'Blink',
                 'Lip Stretch', 'Dimpler', 'Surprise', 'Joy', 'Smile', 'Sadness'] 

# Group data by grade and respondent ID
grouped_data = facial_expressions_data.groupby(["Grade Group", "Respondent"])

# Define a function to select random samples per respondent and specified columns
def select_random_samples(group, columns, num_samples):
    return group[columns].sample(num_samples, replace=True) 

# Create empty lists to store individual respondent data for each column
above_55_data = {col: [] for col in selected_columns}
below_55_data = {col: [] for col in selected_columns}

# Loop through each grade and respondent group and collect random samples for specified columns
for (grade, respondent_id), group in grouped_data:
    for col in selected_columns:
        selected_samples = select_random_samples(group, [col], 15000)[col].tolist()
        if grade == "Above 55":
            above_55_data[col].extend(selected_samples)
        else:
            below_55_data[col].extend(selected_samples)

# Perform the Wilcoxon signed-rank test for each column
for col in selected_columns:
    test_result = wilcoxon(above_55_data[col], below_55_data[col])
    print(f"\nWilcoxon signed-rank test for column {col}:")
    print("Test statistic:", test_result.statistic)
    print("p-value:", test_result.pvalue)

# %%
import pandas as pd

# Convert the dictionaries to DataFrames
df_above_55 = pd.DataFrame(above_55_data)
df_below_55 = pd.DataFrame(below_55_data)

print("Count above: ", df_above_55.count())
print("Count below: ", df_below_55.count())

# Write the DataFrames to CSV files
# df_above_55.to_csv('above_55_data.csv', index=False)
# df_below_55.to_csv('below_55_data.csv', index=False)
# Out:
# Count above:  Contempt       120000
# Smirk          120000
# Eye Widen      120000
# Eye Closure    120000
# Blink          120000
# Lip Stretch    120000
# Dimpler        120000
# Surprise       120000
# Joy            120000
# Smile          120000
# Sadness        120000
# dtype: int64
# Count below:  Contempt       120000
# Smirk          120000
# Eye Widen      120000
# Eye Closure    120000
# Blink          120000
# Lip Stretch    120000
# Dimpler        120000
# Surprise       120000
# Joy            120000
# Smile          120000
# Sadness        120000
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import wilcoxon

# Perform the Wilcoxon signed-rank test for each column and store p-values and mean differences
p_values = []
mean_diffs = []
for col in selected_columns:
    test_result = wilcoxon(above_55_data[col], below_55_data[col])
    p_values.append(test_result.pvalue)
    mean_diff = np.mean(above_55_data[col]) - np.mean(below_55_data[col])
    mean_diffs.append(mean_diff)

# Create a bar plot for mean differences with vertical lines for significance
plt.figure(figsize=(12, 8))
bars = plt.bar(selected_columns, mean_diffs, yerr=None, capsize=5, color='red', alpha=0.7)

# Mark bars where p-value is below 0.05
for i, bar in enumerate(bars):
    plt.axvline(x=i, color='gray', linestyle='--', linewidth=0.5)
    if p_values[i] < 0.05:
        bar.set_color('green')


plt.axhline(0, color='black', linestyle='--', linewidth=1)   # Add a horizontal line at y=0 for reference

plt.xlabel('Facial Expression Columns')
plt.ylabel('Mean Difference')
plt.title('Mean Differences between High Performers and Low Performers')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# <h6>Roll, Pitch, Mouth Open, Lid Tighten, Dimpler, Engagement and Anger were sometimes not significantly different</h6>
