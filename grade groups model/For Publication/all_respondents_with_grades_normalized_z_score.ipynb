# %% [markdown]
# <h1>All Respondents Analysis with Grades Final</h1>

# %% [markdown]
# <h2>Read All Respondents Data</h2>

# %%
import os
import pandas as pd

# Specify the folder path where the CSV files are located
folder_path = "../../all respondents data"

# Initialize an empty dataframe to store the combined data
combined_data = pd.DataFrame()

# Loop through each file in the folder with .csv extension and append to the combined_data dataframe
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path, low_memory=False)
        respondent_num = filename.split('_')[0]  # Get the first part of the filename before the first '_'
        df['Respondent'] = respondent_num  # Add a new column with the respondent number
        combined_data = pd.concat([combined_data, df])

columns_to_remove = ['Row','EventSource','SlideEvent','StimType','Duration',
                     'CollectionPhase','SourceStimuliName','EventSource','SampleNumber','EventSource.1',
                     'Blink', 'BlinkRate', 'EventSource.2','Interocular Distance', 'Gaze X', 'Gaze Y', 'Interpolated Gaze X',
                    'Interpolated Gaze Y', 'Interpolated Distance', 'Fixation Index', 'Fixation Index by Stimulus',
                    'Fixation X', 'Fixation Y', 'Fixation Start', 'Fixation End', 'Saccade Index',
                    'Saccade Index by Stimulus', 'Saccade Start', 'Saccade End', 'Gaze Velocity', 'Gaze Acceleration', 'Fixation Duration',
                    'Fixation Dispersion', 'Saccade Duration', 'Saccade Amplitude',
                    'Saccade Peak Velocity', 'Saccade Peak Acceleration',
                    'Saccade Peak Deceleration', 'Saccade Direction']
combined_data.drop(columns_to_remove, axis=1, inplace=True)

combined_data.head()
# Out:
#    Timestamp     Anger  Contempt   Disgust      Fear       Joy   Sadness  \
# 0  36101.200       NaN       NaN       NaN       NaN       NaN       NaN
# 1  36109.900       NaN       NaN       NaN       NaN       NaN       NaN
# 2  36236.000  0.125566  0.186393  0.023706  0.125796  0.025453  0.125512
# 3  36269.000  0.125833  0.186909  0.023738  0.126169  0.025312  0.125694
# 4  36270.473       NaN       NaN       NaN       NaN       NaN       NaN
#
#    Surprise  Engagement  Valence  ...  Lid Tighten  Mouth Open  Nose Wrinkle  \
# 0       NaN         NaN      NaN  ...          NaN         NaN           NaN
# 1       NaN         NaN      NaN  ...          NaN         NaN           NaN
# 2  0.055428    0.328766      0.0  ...     0.002685    0.027488      0.008689
# 3  0.055510    0.328766      0.0  ...     0.002068    0.027396      0.013201
# 4       NaN         NaN      NaN  ...          NaN         NaN           NaN
#
#       Smile  Smirk  Upper Lip Raise     Pitch       Yaw      Roll  Respondent
# 0       NaN    NaN              NaN       NaN       NaN       NaN         001
# 1       NaN    NaN              NaN       NaN       NaN       NaN         001
# 2  0.443331    0.0         0.000345  6.757946 -1.150817 -0.977193         001
# 3  0.406091    0.0         0.000376  3.458502 -0.160348  0.267830         001
# 4       NaN    NaN              NaN       NaN       NaN       NaN         001
#
# [5 rows x 38 columns]

# %%
print(combined_data)
# Out:
#           Timestamp     Anger  Contempt   Disgust      Fear       Joy  \
# 0         36101.200       NaN       NaN       NaN       NaN       NaN
# 1         36109.900       NaN       NaN       NaN       NaN       NaN
# 2         36236.000  0.125566  0.186393  0.023706  0.125796  0.025453
# 3         36269.000  0.125833  0.186909  0.023738  0.126169  0.025312
# 4         36270.473       NaN       NaN       NaN       NaN       NaN
# ...             ...       ...       ...       ...       ...       ...
# 148355  2522681.800       NaN       NaN       NaN       NaN       NaN
# 148356  2522709.000  0.245047  0.204197  0.028027  0.133038  0.041089
# 148357  2522709.800       NaN       NaN       NaN       NaN       NaN
# 148358  2522831.900       NaN       NaN       NaN       NaN       NaN
# 148359  2522831.900       NaN       NaN       NaN       NaN       NaN
#
#          Sadness  Surprise  Engagement  Valence  ...  Lid Tighten  Mouth Open  \
# 0            NaN       NaN         NaN      NaN  ...          NaN         NaN
# 1            NaN       NaN         NaN      NaN  ...          NaN         NaN
# 2       0.125512  0.055428    0.328766      0.0  ...     0.002685    0.027488
# 3       0.125694  0.055510    0.328766      0.0  ...     0.002068    0.027396
# 4            NaN       NaN         NaN      NaN  ...          NaN         NaN
# ...          ...       ...         ...      ...  ...          ...         ...
# 148355       NaN       NaN         NaN      NaN  ...          NaN         NaN
# 148356  0.118906  0.057576    0.328766      0.0  ...    16.228485    7.659717
# 148357       NaN       NaN         NaN      NaN  ...          NaN         NaN
# 148358       NaN       NaN         NaN      NaN  ...          NaN         NaN
# 148359       NaN       NaN         NaN      NaN  ...          NaN         NaN
#
#         Nose Wrinkle     Smile     Smirk  Upper Lip Raise     Pitch       Yaw  \
# 0                NaN       NaN       NaN              NaN       NaN       NaN
# 1                NaN       NaN       NaN              NaN       NaN       NaN
# 2           0.008689  0.443331  0.000000         0.000345  6.757946 -1.150817
# 3           0.013201  0.406091  0.000000         0.000376  3.458502 -0.160348
# 4                NaN       NaN       NaN              NaN       NaN       NaN
# ...              ...       ...       ...              ...       ...       ...
# 148355           NaN       NaN       NaN              NaN       NaN       NaN
# 148356      0.376117  4.076993  3.261096         0.070152 -0.172043 -1.711222
# 148357           NaN       NaN       NaN              NaN       NaN       NaN
# 148358           NaN       NaN       NaN              NaN       NaN       NaN
# 148359           NaN       NaN       NaN              NaN       NaN       NaN
#
#             Roll  Respondent
# 0            NaN         001
# 1            NaN         001
# 2      -0.977193         001
# 3       0.267830         001
# 4            NaN         001
# ...          ...         ...
# 148355       NaN         019
# 148356 -0.415041         019
# 148357       NaN         019
# 148358       NaN         019
# 148359       NaN         019
#
# [1433385 rows x 38 columns]

# %%
print(combined_data.columns)
# Out:
# Index(['Timestamp', 'Anger', 'Contempt', 'Disgust', 'Fear', 'Joy', 'Sadness',
#        'Surprise', 'Engagement', 'Valence', 'Sentimentality', 'Confusion',
#        'Neutral', 'Attention', 'Brow Furrow', 'Brow Raise', 'Cheek Raise',
#        'Chin Raise', 'Dimpler', 'Eye Closure', 'Eye Widen', 'Inner Brow Raise',
#        'Jaw Drop', 'Lip Corner Depressor', 'Lip Press', 'Lip Pucker',
#        'Lip Stretch', 'Lip Suck', 'Lid Tighten', 'Mouth Open', 'Nose Wrinkle',
#        'Smile', 'Smirk', 'Upper Lip Raise', 'Pitch', 'Yaw', 'Roll',
#        'Respondent'],
#       dtype='object')

# %%
# Specify the columns where NaN values should be removed
columns_to_check = ['Anger', 'Contempt', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise',
       'Engagement', 'Valence', 'Sentimentality', 'Confusion', 'Neutral',
       'Attention', 'Brow Furrow', 'Brow Raise', 'Cheek Raise', 'Chin Raise',
       'Dimpler', 'Eye Closure', 'Eye Widen', 'Inner Brow Raise', 'Jaw Drop',
       'Lip Corner Depressor', 'Lip Press', 'Lip Pucker', 'Lip Stretch',
       'Lip Suck', 'Lid Tighten', 'Mouth Open', 'Nose Wrinkle', 'Smile',
       'Smirk', 'Upper Lip Raise', 'Pitch', 'Yaw', 'Roll']

# Remove rows with NaN values in specified columns
df_combined_cleaned = combined_data.dropna(subset=columns_to_check, how='all')

# Display the DataFrame after removing rows with NaN values
print("\nDataFrame after removing rows with NaN values:")
df_combined_cleaned.head()
# Out:
# DataFrame after removing rows with NaN values:
#     Timestamp     Anger  Contempt   Disgust      Fear       Joy   Sadness  \
# 2     36236.0  0.125566  0.186393  0.023706  0.125796  0.025453  0.125512
# 3     36269.0  0.125833  0.186909  0.023738  0.126169  0.025312  0.125694
# 5     36301.0  0.126258  0.187818  0.023798  0.126605  0.025114  0.125970
# 7     36333.0  0.126290  0.188413  0.023834  0.126583  0.024996  0.126124
# 10    36381.0  0.126344  0.188792  0.023866  0.126641  0.024909  0.126202
#
#     Surprise  Engagement  Valence  ...  Lid Tighten  Mouth Open  Nose Wrinkle  \
# 2   0.055428    0.328766      0.0  ...     0.002685    0.027488      0.008689
# 3   0.055510    0.328766      0.0  ...     0.002068    0.027396      0.013201
# 5   0.055607    0.328766      0.0  ...     0.002222    0.030377      0.019631
# 7   0.055529    0.328766      0.0  ...     0.002643    0.029414      0.022291
# 10  0.055519    0.328766      0.0  ...     0.002665    0.025747      0.033456
#
#        Smile  Smirk  Upper Lip Raise     Pitch       Yaw      Roll  Respondent
# 2   0.443331    0.0         0.000345  6.757946 -1.150817 -0.977193         001
# 3   0.406091    0.0         0.000376  3.458502 -0.160348  0.267830         001
# 5   0.341483    0.0         0.000493  3.753664 -0.737176  0.388438         001
# 7   0.300317    0.0         0.000636  4.180299 -0.449494  0.456045         001
# 10  0.273545    0.0         0.000934  4.626769 -0.389839  0.613328         001
#
# [5 rows x 38 columns]

# %%
df_combined_cleaned.count()
# Out:
# Timestamp               936917
# Anger                   936917
# Contempt                936917
# Disgust                 936917
# Fear                    936917
# Joy                     936917
# Sadness                 936917
# Surprise                936917
# Engagement              936917
# Valence                 936917
# Sentimentality          936917
# Confusion               936917
# Neutral                 936917
# Attention               936917
# Brow Furrow             936917
# Brow Raise              936917
# Cheek Raise             936917
# Chin Raise              936917
# Dimpler                 936917
# Eye Closure             936917
# Eye Widen               936917
# Inner Brow Raise        936917
# Jaw Drop                936917
# Lip Corner Depressor    936917
# Lip Press               936917
# Lip Pucker              936917
# Lip Stretch             936917
# Lip Suck                936917
# Lid Tighten             936917
# Mouth Open              936917
# Nose Wrinkle            936917
# Smile                   936917
# Smirk                   936917
# Upper Lip Raise         936917
# Pitch                   936917
# Yaw                     936917
# Roll                    936917
# Respondent              936917
# dtype: int64

# %% [markdown]
# <h3>Merge Respondents Data with Grades Dataframe</h3>

# %%
import pandas as pd

# Read in the Grades.csv file
grades_df = pd.read_csv('../Grades.csv')

# Remove the trailing underscore from the "Respondent" column in the grades_df dataframe
grades_df['Respondent'] = grades_df['Respondent'].str.rstrip('_')

# Merge the combined_data and grades_df dataframes based on the "Respondent" column
combined_data_with_grades = pd.merge(df_combined_cleaned, grades_df[['Respondent', 'Grade']], on='Respondent')

# Print the resulting dataframe with the added "Grade" column
print(combined_data_with_grades)
# Out:
#         Timestamp     Anger  Contempt   Disgust      Fear       Joy   Sadness  \
# 0         36236.0  0.125566  0.186393  0.023706  0.125796  0.025453  0.125512
# 1         36269.0  0.125833  0.186909  0.023738  0.126169  0.025312  0.125694
# 2         36301.0  0.126258  0.187818  0.023798  0.126605  0.025114  0.125970
# 3         36333.0  0.126290  0.188413  0.023834  0.126583  0.024996  0.126124
# 4         36381.0  0.126344  0.188792  0.023866  0.126641  0.024909  0.126202
# ...           ...       ...       ...       ...       ...       ...       ...
# 882821  2522583.0  0.139795  0.183797  0.026397  0.130016  0.045364  0.117328
# 882822  2522615.0  0.153553  0.176831  0.026905  0.128566  0.046042  0.116635
# 882823  2522647.0  0.168653  0.193708  0.027669  0.130344  0.045429  0.117382
# 882824  2522681.0  0.195341  0.187637  0.027562  0.130503  0.043328  0.117269
# 882825  2522709.0  0.245047  0.204197  0.028027  0.133038  0.041089  0.118906
#
#         Surprise  Engagement  Valence  ...  Mouth Open  Nose Wrinkle  \
# 0       0.055428    0.328766      0.0  ...    0.027488      0.008689
# 1       0.055510    0.328766      0.0  ...    0.027396      0.013201
# 2       0.055607    0.328766      0.0  ...    0.030377      0.019631
# 3       0.055529    0.328766      0.0  ...    0.029414      0.022291
# 4       0.055519    0.328766      0.0  ...    0.025747      0.033456
# ...          ...         ...      ...  ...         ...           ...
# 882821  0.060181    0.328766      0.0  ...    6.647667      0.457276
# 882822  0.058846    0.328766      0.0  ...    6.861856      0.512176
# 882823  0.058326    0.328766      0.0  ...    7.472722      0.519497
# 882824  0.057809    0.328766      0.0  ...    7.365998      0.463937
# 882825  0.057576    0.328766      0.0  ...    7.659717      0.376117
#
#            Smile     Smirk  Upper Lip Raise     Pitch       Yaw      Roll  \
# 0       0.443331  0.000000         0.000345  6.757946 -1.150817 -0.977193
# 1       0.406091  0.000000         0.000376  3.458502 -0.160348  0.267830
# 2       0.341483  0.000000         0.000493  3.753664 -0.737176  0.388438
# 3       0.300317  0.000000         0.000636  4.180299 -0.449494  0.456045
# 4       0.273545  0.000000         0.000934  4.626769 -0.389839  0.613328
# ...          ...       ...              ...       ...       ...       ...
# 882821  4.720551  2.773993         0.106491  1.251196 -1.319161 -0.530024
# 882822  4.703412  2.382556         0.255912  0.392811 -1.608518 -0.468374
# 882823  4.585781  3.149543         0.253990  0.286135 -1.387060 -0.229705
# 882824  4.418400  2.717841         0.150040 -1.702013 -1.998969 -0.185392
# 882825  4.076993  3.261096         0.070152 -0.172043 -1.711222 -0.415041
#
#         Respondent  Grade
# 0              001    100
# 1              001    100
# 2              001    100
# 3              001    100
# 4              001    100
# ...            ...    ...
# 882821         019     55
# 882822         019     55
# 882823         019     55
# 882824         019     55
# 882825         019     55
#
# [882826 rows x 39 columns]

# %%
combined_data_with_grades.head()
# Out:
#    Timestamp     Anger  Contempt   Disgust      Fear       Joy   Sadness  \
# 0    36236.0  0.125566  0.186393  0.023706  0.125796  0.025453  0.125512
# 1    36269.0  0.125833  0.186909  0.023738  0.126169  0.025312  0.125694
# 2    36301.0  0.126258  0.187818  0.023798  0.126605  0.025114  0.125970
# 3    36333.0  0.126290  0.188413  0.023834  0.126583  0.024996  0.126124
# 4    36381.0  0.126344  0.188792  0.023866  0.126641  0.024909  0.126202
#
#    Surprise  Engagement  Valence  ...  Mouth Open  Nose Wrinkle     Smile  \
# 0  0.055428    0.328766      0.0  ...    0.027488      0.008689  0.443331
# 1  0.055510    0.328766      0.0  ...    0.027396      0.013201  0.406091
# 2  0.055607    0.328766      0.0  ...    0.030377      0.019631  0.341483
# 3  0.055529    0.328766      0.0  ...    0.029414      0.022291  0.300317
# 4  0.055519    0.328766      0.0  ...    0.025747      0.033456  0.273545
#
#    Smirk  Upper Lip Raise     Pitch       Yaw      Roll  Respondent  Grade
# 0    0.0         0.000345  6.757946 -1.150817 -0.977193         001    100
# 1    0.0         0.000376  3.458502 -0.160348  0.267830         001    100
# 2    0.0         0.000493  3.753664 -0.737176  0.388438         001    100
# 3    0.0         0.000636  4.180299 -0.449494  0.456045         001    100
# 4    0.0         0.000934  4.626769 -0.389839  0.613328         001    100
#
# [5 rows x 39 columns]

# %%
print(combined_data_with_grades.columns)
# Out:
# Index(['Timestamp', 'Anger', 'Contempt', 'Disgust', 'Fear', 'Joy', 'Sadness',
#        'Surprise', 'Engagement', 'Valence', 'Sentimentality', 'Confusion',
#        'Neutral', 'Attention', 'Brow Furrow', 'Brow Raise', 'Cheek Raise',
#        'Chin Raise', 'Dimpler', 'Eye Closure', 'Eye Widen', 'Inner Brow Raise',
#        'Jaw Drop', 'Lip Corner Depressor', 'Lip Press', 'Lip Pucker',
#        'Lip Stretch', 'Lip Suck', 'Lid Tighten', 'Mouth Open', 'Nose Wrinkle',
#        'Smile', 'Smirk', 'Upper Lip Raise', 'Pitch', 'Yaw', 'Roll',
#        'Respondent', 'Grade'],
#       dtype='object')

# %% [markdown]
# <h2>Facial Expressions Analysis</h2>

# %% [markdown]
# <h3>Data Pre-processing</h3>

# %%
import pandas as pd

facial_expressions_columns = ['Respondent', 'Grade','Anger', 'Contempt', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise',
       'Engagement', 'Valence', 'Sentimentality', 'Confusion', 'Neutral',
       'Attention', 'Brow Furrow', 'Brow Raise', 'Cheek Raise', 'Chin Raise',
       'Dimpler', 'Eye Closure', 'Eye Widen', 'Inner Brow Raise', 'Jaw Drop',
       'Lip Corner Depressor', 'Lip Press', 'Lip Pucker', 'Lip Stretch',
       'Lip Suck', 'Lid Tighten', 'Mouth Open', 'Nose Wrinkle', 'Smile',
       'Smirk', 'Upper Lip Raise', 'Pitch', 'Yaw',
       'Roll']
# Creating a copy df with only the facial expressions data
facial_expressions_data = combined_data_with_grades[facial_expressions_columns].copy()

# Remove rows with all NaN values, except in the 'Respondent' column
facial_expressions_data = facial_expressions_data.dropna(how='all', 
                                                         subset=facial_expressions_data.columns.difference(['Respondent', 'Grade']))

facial_expressions_data
# Out:
#        Respondent  Grade     Anger  Contempt   Disgust      Fear       Joy  \
# 0             001    100  0.125566  0.186393  0.023706  0.125796  0.025453
# 1             001    100  0.125833  0.186909  0.023738  0.126169  0.025312
# 2             001    100  0.126258  0.187818  0.023798  0.126605  0.025114
# 3             001    100  0.126290  0.188413  0.023834  0.126583  0.024996
# 4             001    100  0.126344  0.188792  0.023866  0.126641  0.024909
# ...           ...    ...       ...       ...       ...       ...       ...
# 882821        019     55  0.139795  0.183797  0.026397  0.130016  0.045364
# 882822        019     55  0.153553  0.176831  0.026905  0.128566  0.046042
# 882823        019     55  0.168653  0.193708  0.027669  0.130344  0.045429
# 882824        019     55  0.195341  0.187637  0.027562  0.130503  0.043328
# 882825        019     55  0.245047  0.204197  0.028027  0.133038  0.041089
#
#          Sadness  Surprise  Engagement  ...  Lip Suck  Lid Tighten  \
# 0       0.125512  0.055428    0.328766  ...  0.000806     0.002685
# 1       0.125694  0.055510    0.328766  ...  0.002314     0.002068
# 2       0.125970  0.055607    0.328766  ...  0.003132     0.002222
# 3       0.126124  0.055529    0.328766  ...  0.003382     0.002643
# 4       0.126202  0.055519    0.328766  ...  0.003895     0.002665
# ...          ...       ...         ...  ...       ...          ...
# 882821  0.117328  0.060181    0.328766  ...  0.125971     2.270765
# 882822  0.116635  0.058846    0.328766  ...  0.129171     4.729377
# 882823  0.117382  0.058326    0.328766  ...  0.135208     6.785742
# 882824  0.117269  0.057809    0.328766  ...  0.135131    10.632483
# 882825  0.118906  0.057576    0.328766  ...  0.144891    16.228485
#
#         Mouth Open  Nose Wrinkle     Smile     Smirk  Upper Lip Raise  \
# 0         0.027488      0.008689  0.443331  0.000000         0.000345
# 1         0.027396      0.013201  0.406091  0.000000         0.000376
# 2         0.030377      0.019631  0.341483  0.000000         0.000493
# 3         0.029414      0.022291  0.300317  0.000000         0.000636
# 4         0.025747      0.033456  0.273545  0.000000         0.000934
# ...            ...           ...       ...       ...              ...
# 882821    6.647667      0.457276  4.720551  2.773993         0.106491
# 882822    6.861856      0.512176  4.703412  2.382556         0.255912
# 882823    7.472722      0.519497  4.585781  3.149543         0.253990
# 882824    7.365998      0.463937  4.418400  2.717841         0.150040
# 882825    7.659717      0.376117  4.076993  3.261096         0.070152
#
#            Pitch       Yaw      Roll
# 0       6.757946 -1.150817 -0.977193
# 1       3.458502 -0.160348  0.267830
# 2       3.753664 -0.737176  0.388438
# 3       4.180299 -0.449494  0.456045
# 4       4.626769 -0.389839  0.613328
# ...          ...       ...       ...
# 882821  1.251196 -1.319161 -0.530024
# 882822  0.392811 -1.608518 -0.468374
# 882823  0.286135 -1.387060 -0.229705
# 882824 -1.702013 -1.998969 -0.185392
# 882825 -0.172043 -1.711222 -0.415041
#
# [882826 rows x 38 columns]

# %% [markdown]
# <h2>Compare Facial Expressions by Grade Group</h2>

# %%
from tabulate import tabulate

# Add a new column to the combined_data_with_grades dataframe that indicates whether the grade is above or below 55
facial_expressions_data['Grade Group'] = facial_expressions_data['Grade'].apply(lambda x: 'Above 55' if x > 55 else 'Below 55')

# Describe statistics for each selected column by grade group
selected_columns = ['Anger', 'Contempt', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise',
       'Engagement', 'Valence', 'Sentimentality', 'Confusion', 'Neutral',
       'Attention', 'Brow Furrow', 'Brow Raise', 'Cheek Raise', 'Chin Raise',
       'Dimpler', 'Eye Closure', 'Eye Widen', 'Inner Brow Raise', 'Jaw Drop',
       'Lip Corner Depressor', 'Lip Press', 'Lip Pucker', 'Lip Stretch',
       'Lip Suck', 'Lid Tighten', 'Mouth Open', 'Nose Wrinkle', 'Smile',
       'Smirk', 'Upper Lip Raise', 'Pitch', 'Yaw',
       'Roll']

# %% [markdown]
# <h3>Count data points for each respondent and each Grade Group</h3>

# %% [markdown]
# <h2>Correlation Between Emotions and Grade</h2>

# %% [markdown]
# <h3>Z-Score Normalization</h3>

# %% [markdown]
# <h6>Normalize the mean to 0 and standard diviation to 1</h6>

# %%
from sklearn.preprocessing import StandardScaler

participant_ids = facial_expressions_data['Respondent'].unique()

for participant_id in participant_ids:
    # Select data for the current participant
    participant_data = facial_expressions_data[facial_expressions_data['Respondent'] == participant_id]
    
    # Create a subset of the participant's data with only selected columns
    subset_data = participant_data[selected_columns]

    # Initialize the StandardScaler
    scaler = StandardScaler()

    # Fit and transform the selected columns within the participant
    normalized_data = scaler.fit_transform(subset_data)

    # Replace the original numeric columns in the DataFrame with the normalized values
    facial_expressions_data.loc[facial_expressions_data['Respondent'] == participant_id, selected_columns] = normalized_data

# %%
facial_expressions_data.head()
# Out:
#   Respondent  Grade     Anger  Contempt   Disgust      Fear       Joy  \
# 0        001    100 -0.315468 -0.023213 -0.108675 -0.253119 -0.264283
# 1        001    100 -0.315388 -0.022973 -0.108665 -0.253050 -0.264289
# 2        001    100 -0.315261 -0.022552 -0.108646 -0.252968 -0.264298
# 3        001    100 -0.315251 -0.022276 -0.108635 -0.252972 -0.264303
# 4        001    100 -0.315235 -0.022100 -0.108625 -0.252961 -0.264307
#
#     Sadness  Surprise  Engagement  ...  Lid Tighten  Mouth Open  Nose Wrinkle  \
# 0 -0.062689 -0.145416   -0.659977  ...    -0.159832   -0.763884     -0.230346
# 1 -0.062618 -0.145397   -0.659977  ...    -0.159918   -0.763886     -0.229139
# 2 -0.062510 -0.145375   -0.659977  ...    -0.159896   -0.763807     -0.227419
# 3 -0.062450 -0.145393   -0.659977  ...    -0.159838   -0.763832     -0.226708
# 4 -0.062419 -0.145395   -0.659977  ...    -0.159835   -0.763930     -0.223722
#
#       Smile    Smirk  Upper Lip Raise     Pitch       Yaw      Roll  \
# 0 -0.362405 -0.14355        -0.237447  2.168331  0.003525  0.139069
# 1 -0.364031 -0.14355        -0.237444  1.738758  0.140313  0.414367
# 2 -0.366853 -0.14355        -0.237432  1.777186  0.060650  0.441036
# 3 -0.368651 -0.14355        -0.237418  1.832732  0.100381  0.455985
# 4 -0.369820 -0.14355        -0.237388  1.890861  0.108619  0.490763
#
#    Grade Group
# 0     Above 55
# 1     Above 55
# 2     Above 55
# 3     Above 55
# 4     Above 55
#
# [5 rows x 39 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

selected_columns = ['Anger', 'Contempt', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise',
                    'Engagement', 'Valence', 'Sentimentality', 'Confusion', 'Neutral',
                    'Attention', 'Brow Furrow', 'Brow Raise', 'Cheek Raise', 'Chin Raise',
                    'Dimpler', 'Eye Closure', 'Eye Widen', 'Inner Brow Raise', 'Jaw Drop',
                    'Lip Corner Depressor', 'Lip Press', 'Lip Pucker', 'Lip Stretch',
                    'Lip Suck', 'Lid Tighten', 'Mouth Open', 'Nose Wrinkle', 'Smile',
                    'Smirk', 'Upper Lip Raise', 'Pitch', 'Yaw', 'Roll']

# Assuming 'facial_expressions_data' is your DataFrame
plt.figure(figsize=(15, 10))  # Adjust figure size as needed

for col in selected_columns:
    plt.subplot(4, 9, selected_columns.index(col) + 1)  # Adjust layout based on the number of columns
    sns.histplot(data=facial_expressions_data, x=col, kde=True, bins=20)
    plt.title(f'Histogram of {col}')
    plt.xlabel('Values')
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Compare the Grade Groups</h3>

# %% [markdown]
# <h5>Using non-parametric statistical test, since the data distribution is not normal. Only Pitch seems to have normal distribution. Since the data is not ordered, since those are measures at different timestamps and therefore have no order, chose to use Wilcoxon statistical test</h6>

# %%
import pandas as pd
from scipy.stats import wilcoxon
import matplotlib.pyplot as plt

selected_columns = ['Anger', 'Contempt', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise',
       'Engagement', 'Valence', 'Sentimentality', 'Confusion', 'Neutral',
       'Attention', 'Brow Furrow', 'Brow Raise', 'Cheek Raise', 'Chin Raise',
       'Dimpler', 'Eye Closure', 'Eye Widen', 'Inner Brow Raise', 'Jaw Drop',
       'Lip Corner Depressor', 'Lip Press', 'Lip Pucker', 'Lip Stretch',
       'Lip Suck', 'Lid Tighten', 'Mouth Open', 'Nose Wrinkle', 'Smile',
       'Smirk', 'Upper Lip Raise', 'Pitch', 'Yaw',
       'Roll']

# Group data by grade and respondent ID
grouped_data = facial_expressions_data.groupby(["Grade Group", "Respondent"])

# Define a function to select random samples per respondent and specified columns
def select_random_samples(group, columns, num_samples):
    return group[columns].sample(num_samples, replace=True) 

# Create empty lists to store individual respondent data for each column
above_55_data = {col: [] for col in selected_columns}
below_55_data = {col: [] for col in selected_columns}

# Loop through each grade and respondent group and collect random samples for specified columns
for (grade, respondent_id), group in grouped_data:
    for col in selected_columns:
        selected_samples = select_random_samples(group, [col], 10000)[col].tolist()
        if grade == "Above 55":
            above_55_data[col].extend(selected_samples)
        else:
            below_55_data[col].extend(selected_samples)

# Perform the Wilcoxon signed-rank test for each column
for col in selected_columns:
    test_result = wilcoxon(above_55_data[col], below_55_data[col])
    print(f"\nWilcoxon signed-rank test for column {col}:")
    print("Test statistic:", test_result.statistic)
    print("p-value:", test_result.pvalue)
# Out:
# Wilcoxon signed-rank test for column Anger:
# Test statistic: 1590734229.0
# p-value: 0.1551498920398596
#
# Wilcoxon signed-rank test for column Contempt:
# Test statistic: 816570691.0
# p-value: 0.0
#
# Wilcoxon signed-rank test for column Disgust:
# Test statistic: 1357310951.0
# p-value: 3.4129539702880405e-302
#
# Wilcoxon signed-rank test for column Fear:
# Test statistic: 1538695776.0
# p-value: 6.101807767376396e-21
#
# Wilcoxon signed-rank test for column Joy:
# Test statistic: 1536480267.0
# p-value: 2.303975243550544e-22
#
# Wilcoxon signed-rank test for column Sadness:
# Test statistic: 1302289280.0
# p-value: 0.0
#
# Wilcoxon signed-rank test for column Surprise:
# Test statistic: 1426792762.0
# p-value: 5.753082211812037e-155
#
# Wilcoxon signed-rank test for column Engagement:
# Test statistic: 1594075307.0
# p-value: 0.36277179274878735
#
# Wilcoxon signed-rank test for column Valence:
# Test statistic: 1553735240.0
# p-value: 1.3289206541776504e-12
#
# Wilcoxon signed-rank test for column Sentimentality:
# Test statistic: 1376115799.0
# p-value: 1.6771248952571204e-257
#
# Wilcoxon signed-rank test for column Confusion:
# Test statistic: 1562317658.0
# p-value: 7.837582018450986e-09
#
# Wilcoxon signed-rank test for column Neutral:
# Test statistic: 1358942723.0
# p-value: 3.5784196724238035e-298
#
# Wilcoxon signed-rank test for column Attention:
# Test statistic: 1562458506.0
# p-value: 8.905784334418647e-09
#
# Wilcoxon signed-rank test for column Brow Furrow:
# Test statistic: 1478548581.0
# p-value: 3.4450323712158816e-77
#
# Wilcoxon signed-rank test for column Brow Raise:
# Test statistic: 1540478075.0
# p-value: 7.840034929135225e-20
#
# Wilcoxon signed-rank test for column Cheek Raise:
# Test statistic: 1510568388.0
# p-value: 1.0981806945457158e-42
#
# Wilcoxon signed-rank test for column Chin Raise:
# Test statistic: 1405206696.0
# p-value: 1.8918935406017936e-195
#
# Wilcoxon signed-rank test for column Dimpler:
# Test statistic: 1563918496.0
# p-value: 3.254786098345444e-08
#
# Wilcoxon signed-rank test for column Eye Closure:
# Test statistic: 1092915423.0
# p-value: 0.0
#
# Wilcoxon signed-rank test for column Eye Widen:
# Test statistic: 1360539502.0
# p-value: 2.896106278255358e-294
#
# Wilcoxon signed-rank test for column Inner Brow Raise:
# Test statistic: 1538690000.0
# p-value: 6.0508025850911694e-21
#
# Wilcoxon signed-rank test for column Jaw Drop:
# Test statistic: 1504189247.0
# p-value: 9.90369096986155e-49
#
# Wilcoxon signed-rank test for column Lip Corner Depressor:
# Test statistic: 1278184158.0
# p-value: 0.0
#
# Wilcoxon signed-rank test for column Lip Press:
# Test statistic: 1430954984.0
# p-value: 1.0498558311997351e-147
#
# Wilcoxon signed-rank test for column Lip Pucker:
# Test statistic: 1534847452.0
# p-value: 1.9146608893271085e-23
#
# Wilcoxon signed-rank test for column Lip Stretch:
# Test statistic: 1423107652.0
# p-value: 1.5277573680747106e-161
#
# Wilcoxon signed-rank test for column Lip Suck:
# Test statistic: 1539669304.0
# p-value: 2.4837243488519546e-20
#
# Wilcoxon signed-rank test for column Lid Tighten:
# Test statistic: 1571641503.0
# p-value: 1.3958586625463586e-05
#
# Wilcoxon signed-rank test for column Mouth Open:
# Test statistic: 1592357710.0
# p-value: 0.2407826524863773
#
# Wilcoxon signed-rank test for column Nose Wrinkle:
# Test statistic: 1385819625.0
# p-value: 7.582926381173792e-236
#
# Wilcoxon signed-rank test for column Smile:
# Test statistic: 1475160788.0
# p-value: 1.8976259487310978e-81
#
# Wilcoxon signed-rank test for column Smirk:
# Test statistic: 1189913608.0
# p-value: 0.0
#
# Wilcoxon signed-rank test for column Upper Lip Raise:
# Test statistic: 1528393452.0
# p-value: 5.603472654329738e-28
#
# Wilcoxon signed-rank test for column Pitch:
# Test statistic: 1593398928.0
# p-value: 0.3107588625646611
#
# Wilcoxon signed-rank test for column Yaw:
# Test statistic: 1572310120.0
# p-value: 2.213867554126225e-05
#
# Wilcoxon signed-rank test for column Roll:
# Test statistic: 1588361944.0
# p-value: 0.0743016650211209

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import wilcoxon

# Perform the Wilcoxon signed-rank test for each column and store p-values and mean differences
p_values = []
mean_diffs = []
for col in selected_columns:
    test_result = wilcoxon(above_55_data[col], below_55_data[col])
    p_values.append(test_result.pvalue)
    mean_diff = np.mean(above_55_data[col]) - np.mean(below_55_data[col])
    mean_diffs.append(mean_diff)

# Create a bar plot for mean differences with vertical lines for significance
plt.figure(figsize=(12, 8))
bars = plt.bar(selected_columns, mean_diffs, yerr=None, capsize=5, color='red', alpha=0.7)

# Mark bars where p-value is below 0.05
for i, bar in enumerate(bars):
    plt.axvline(x=i, color='gray', linestyle='--', linewidth=0.5)
    if p_values[i] < 0.05:
        bar.set_color('green')


plt.axhline(0, color='black', linestyle='--', linewidth=1)   # Add a horizontal line at y=0 for reference

plt.xlabel('Facial Expression Columns')
plt.ylabel('Mean Difference')
plt.title('Mean Differences between Grade Groups with Significance Marked')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# <h6>Roll, Pitch, Mouth Open, Lid Tighten, Dimpler, Engagement and Anger were sometimes not significantly different</h6>
